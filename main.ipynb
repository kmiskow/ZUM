# %%
from datasets import datasetManager
from one_class_algorithms import isolation_forest,elliptic_envelope, one_class_svm

# %%
dm = datasetManager()
X,y_true = dm.blobs()

# %%
print("Metrics for isolation forest")
isolation_forest(X,y_true,debug = True)
print("Metrics for Elliptic Envelope")
elliptic_envelope(X,y_true,debug = True)
print("Metrics for One class SVM")
one_class_svm(X,y_true,debug = True)
# Out:
# Metrics for isolation forest
# True Positives (TP): 16
# True Negatives (TN): 284
# False Positives (FP): 16
# False Negatives (FN): 4
# Precision: 0.50
# Recall: 0.80
# F1 Score: 0.62
# Accuracy: 0.94
# Metrics for Elliptic Envelope
# True Positives (TP): 0
# True Negatives (TN): 268
# False Positives (FP): 32
# False Negatives (FN): 20
# Precision: 0.00
# Recall: 0.00
# F1 Score: 0.00
# Accuracy: 0.84
# Metrics for One class SVM
# True Positives (TP): 16
# True Negatives (TN): 283
# False Positives (FP): 17
# False Negatives (FN): 4
# Precision: 0.48
# Recall: 0.80
# F1 Score: 0.60
# Accuracy: 0.93

# %%
X,y_true = dm.moons()

# %%
print("Metrics for isolation forest")
isolation_forest(X,y_true,debug = True)
print("Metrics for Elliptic Envelope")
elliptic_envelope(X,y_true,debug = True)
print("Metrics for One class SVM")
one_class_svm(X,y_true,debug = True)
# Out:
# Metrics for isolation forest
# True Positives (TP): 16
# True Negatives (TN): 284
# False Positives (FP): 16
# False Negatives (FN): 4
# Precision: 0.50
# Recall: 0.80
# F1 Score: 0.62
# Accuracy: 0.94
# Metrics for Elliptic Envelope
# True Positives (TP): 15
# True Negatives (TN): 283
# False Positives (FP): 17
# False Negatives (FN): 5
# Precision: 0.47
# Recall: 0.75
# F1 Score: 0.58
# Accuracy: 0.93
# Metrics for One class SVM
# True Positives (TP): 14
# True Negatives (TN): 282
# False Positives (FP): 18
# False Negatives (FN): 6
# Precision: 0.44
# Recall: 0.70
# F1 Score: 0.54
# Accuracy: 0.93
